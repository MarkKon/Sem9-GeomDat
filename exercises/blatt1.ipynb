# %%
import matplotlib.pyplot as plt
import numpy as np
import src.utils as utils

# %% [markdown]
# 8. Illustriere die Ellipse $c(t) = (2\cos(t), \sin(t))$ mit PYTHON

# %%
# %config InlineBackend.figure_format='svg'
fig, ax = plt.subplots(figsize=(10,5))
ax = utils.cartesian_coordinates(ax, xlim=(-4, 4), ylim=(-3, 3), ticks_frequency=1)
t = np.linspace(0, 2*np.pi,100)
plt.plot(2*np.cos(t), np.sin(t))
plt.show()
